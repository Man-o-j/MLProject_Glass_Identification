# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### **Importing Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Reading Dataset**

# %%
glass = pd.read_csv("/content/glass.csv")

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
glass['Type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %% [markdown]
# ### **Exploring Dataset:**
#
# *   Shape of Dataset
# *   Sample of head and tail of Dataset
#
# *   Datatype of Dataset
# *   Count of unique Values in Dataset
#
# *   Null count in Dataset
# *   Information of Dataset
#
# *   Statistics of Dataset

# %%
glass.shape
# Out:
# (214, 10)

# %%
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
glass.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
glass.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
glass.value_counts() #Return a Series containing counts of unique values
# Out:
# RI       Na     Mg    Al    Si     K     Ca     Ba    Fe    Type
# 1.52213  14.21  3.82  0.47  71.77  0.11  9.57   0.00  0.00  1       2
# 1.51115  17.38  0.00  0.34  75.41  0.00  6.65   0.00  0.00  6       1
# 1.51848  13.64  3.87  1.27  71.96  0.54  8.32   0.00  0.32  2       1
# 1.51831  14.39  0.00  1.82  72.86  1.41  6.47   2.88  0.00  7       1
# 1.51832  13.33  3.34  1.54  72.14  0.56  8.99   0.00  0.00  3       1
#                                                                    ..
# 1.51707  13.48  3.48  1.71  72.52  0.62  7.99   0.00  0.00  2       1
# 1.51708  13.72  3.68  1.81  72.06  0.64  7.88   0.00  0.00  2       1
# 1.51709  13.00  3.47  1.79  72.72  0.66  8.18   0.00  0.00  2       1
# 1.51711  12.89  3.62  1.57  72.96  0.61  8.11   0.00  0.00  2       1
# 1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.00  0.24  2       1
# Length: 213, dtype: int64

# %%
nullcount = glass.isna().sum()
nullcount
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
glass.describe().T
# Out:
#       count       mean       std       min        25%       50%        75%  \
# RI    214.0   1.518365  0.003037   1.51115   1.516522   1.51768   1.519157
# Na    214.0  13.407850  0.816604  10.73000  12.907500  13.30000  13.825000
# Mg    214.0   2.684533  1.442408   0.00000   2.115000   3.48000   3.600000
# Al    214.0   1.444907  0.499270   0.29000   1.190000   1.36000   1.630000
# Si    214.0  72.650935  0.774546  69.81000  72.280000  72.79000  73.087500
# K     214.0   0.497056  0.652192   0.00000   0.122500   0.55500   0.610000
# Ca    214.0   8.956963  1.423153   5.43000   8.240000   8.60000   9.172500
# Ba    214.0   0.175047  0.497219   0.00000   0.000000   0.00000   0.000000
# Fe    214.0   0.057009  0.097439   0.00000   0.000000   0.00000   0.100000
# Type  214.0   2.780374  2.103739   1.00000   1.000000   2.00000   3.000000
#
#            max
# RI     1.53393
# Na    17.38000
# Mg     4.49000
# Al     3.50000
# Si    75.41000
# K      6.21000
# Ca    16.19000
# ...

# %% [markdown]
# # **Data Visualization**

# %%
glass.plot()

# %%
glass.plot(kind ='hist',y='Type')
plt.show()

# %%
glass.plot(kind ='scatter',x='RI',y='Type')
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
features = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']
label = ['Type']

X = glass[features]
y = glass[label]

# %%
col = X.values


for i in range(0,9):
        skew = glass[features[i]].skew()
        sns.distplot(glass[features[i]], label='Skew = %.3f' %(skew), bins=30)
        plt.legend(loc='best')
        plt.xlabel(features[i])
        plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import seaborn as sns

plt.figure(figsize=(10,10))
sns.pairplot(data=glass)
plt.show()

# %%
sns.set(style = 'whitegrid')
for i in range(0,9):
       sns.violinplot(x = "Type" , y = features[i] , data = glass)
       plt.ylabel(features[i])
       plt.show()

# %%
for i in range(0,9):
       sns.boxplot(x = "Type" , y = features[i] , data = glass)
       plt.ylabel(features[i])
       plt.show()

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ### **Checking the presence of null values in the Dataset**

# %%
glass.isna().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled = pd.DataFrame(X)

# %% [markdown]
# ### **Checking Outliers in the Dataset and Removing the Outliers**

# %%
for i in range(0,9):
       sns.boxplot(x = features[i],data = glass)
       plt.ylabel(features[i])
       plt.show()

# %%
print("Outliers of RI:")
glass[(glass["RI"] < 1.512) | (glass["RI"] > 1.525)]
# Out:
# Outliers of RI:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe  Type
# 47   1.52667  13.99  3.70  0.71  71.57  0.02   9.82  0.00  0.10     1
# 103  1.52725  13.80  3.15  0.66  70.57  0.08  11.64  0.00  0.00     2
# 106  1.53125  10.73  0.00  2.10  69.81  0.58  13.30  3.15  0.28     2
# 107  1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.00  0.24     2
# 110  1.52664  11.23  0.00  0.77  73.21  0.00  14.68  0.00  0.00     2
# 111  1.52739  11.02  0.00  0.75  73.08  0.00  14.96  0.00  0.00     2
# 112  1.52777  12.64  0.00  0.67  72.02  0.06  14.40  0.00  0.00     2
# 131  1.52614  13.70  0.00  1.36  71.24  0.19  13.44  0.00  0.10     2
# 184  1.51115  17.38  0.00  0.34  75.41  0.00   6.65  0.00  0.00     6
# 185  1.51131  13.69  3.20  1.81  72.81  1.76   5.43  1.19  0.00     7

# %%
glass=glass[(glass["RI"] > 1.512) & (glass["RI"] < 1.525)]

# %%
print("Outliers of Na:")
glass[(glass["Na"] < 11.5) | (glass["Na"] > 15.5)]
# Out:
# Outliers of Na:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe  Type
# 105  1.52475  11.45  0.00  1.88  72.19  0.81  13.24  0.00  0.34     2
# 166  1.52151  11.03  1.71  1.56  73.44  0.58  11.62  0.00  0.00     5
# 189  1.52365  15.79  1.83  1.31  70.43  0.31   8.61  1.68  0.00     7

# %%
glass=glass[(glass["Na"] > 11.5) & (glass["Na"] < 15.5)]

# %%
print("Outliers of Al:")
glass[(glass["Al"] < 0.5) | (glass["Al"] > 2.5)]
# Out:
# Outliers of Al:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 21   1.51966  14.77  3.75  0.29  72.02  0.03  9.00  0.00  0.00     1
# 38   1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.00  0.00     1
# 39   1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.00  0.00     1
# 163  1.51514  14.01  2.68  3.50  69.89  1.68  5.87  2.20  0.00     5
# 171  1.51316  13.02  0.00  3.04  70.48  6.21  6.96  0.00  0.00     5
# 172  1.51321  13.00  0.00  3.02  70.70  6.21  6.93  0.00  0.00     5
# 192  1.51623  14.20  0.00  2.79  73.46  0.04  9.04  0.40  0.09     7
# 195  1.51545  14.14  0.00  2.68  73.39  0.08  9.07  0.61  0.05     7
# 196  1.51556  13.87  0.00  2.54  73.23  0.14  9.41  0.81  0.01     7
# 198  1.51531  14.38  0.00  2.66  73.10  0.04  9.08  0.64  0.00     7
# 199  1.51609  15.01  0.00  2.51  73.05  0.05  8.83  0.53  0.00     7
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00     7
# ...

# %%
glass=glass[(glass["Al"] > 0.5) & (glass["Al"] < 2.5)]

# %%
print("Outliers of Si:")
glass[(glass["Si"] < 71) | (glass["Si"] > 74)]
# Out:
# Outliers of Si:
#           RI     Na    Mg    Al     Si     K     Ca   Ba   Fe  Type
# 109  1.51818  13.72  0.00  0.56  74.45  0.00  10.99  0.0  0.0     2
# 180  1.51299  14.40  1.74  1.54  74.55  0.00   7.59  0.0  0.0     6
# 188  1.52247  14.86  2.20  2.06  70.26  0.76   9.76  0.0  0.0     7
# 201  1.51653  11.95  0.00  1.19  75.18  2.70   8.93  0.0  0.0     7

# %%
glass=glass[(glass["Si"] > 71) & (glass["Si"] < 74)]

# %%
print("Outliers of K:")
glass[(glass["K"] > 1.5)]
# Out:
# Outliers of K:
# Empty DataFrame
# Columns: [RI, Na, Mg, Al, Si, K, Ca, Ba, Fe, Type]
# Index: []

# %%
glass=glass[(glass["K"] < 1.5)]

# %%
print("Outliers of Ca:")
glass[(glass["Ca"] < 7) | (glass["Ca"] > 12)]
# Out:
# Outliers of Ca:
#           RI     Na    Mg    Al     Si     K     Ca    Ba   Fe  Type
# 170  1.52369  13.44  0.00  1.58  72.22  0.32  12.24  0.00  0.0     5
# 173  1.52043  13.38  0.00  1.40  72.25  0.33  12.50  0.00  0.0     5
# 186  1.51838  14.32  3.26  2.22  71.25  1.46   5.79  1.63  0.0     7
# 207  1.51831  14.39  0.00  1.82  72.86  1.41   6.47  2.88  0.0     7

# %%
glass=glass[(glass["Ca"] > 7) & (glass["Ca"] < 12)]

# %%
print("Outliers of Fe:")
glass[(glass["Fe"] > 0.3)]
# Out:
# Outliers of Fe:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 56   1.51215  12.99  3.47  1.12  72.98  0.62  8.35  0.00  0.31     1
# 71   1.51848  13.64  3.87  1.27  71.96  0.54  8.32  0.00  0.32     2
# 145  1.51839  12.85  3.67  1.24  72.57  0.62  8.68  0.00  0.35     2
# 162  1.52211  14.19  3.78  0.91  71.36  0.23  9.14  0.00  0.37     3
# 174  1.52058  12.85  1.61  2.17  72.18  0.76  9.70  0.24  0.51     5

# %%
glass=glass[(glass["Fe"] < 0.3)]

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 206  1.51645  14.94  0.00  1.87  73.11  0.00  8.67  1.38  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [174 rows x 10 columns]

# %% [markdown]
# ### **Finding Correlation of the dataset between all the columns**

# %%
glass.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000  0.093844  0.001069 -0.535728 -0.585719 -0.392478  0.728543
# Na    0.093844  1.000000 -0.554012  0.285551 -0.239509 -0.711340  0.078712
# Mg    0.001069 -0.554012  1.000000 -0.574187 -0.379964  0.521925 -0.437084
# Al   -0.535728  0.285551 -0.574187  1.000000  0.365415 -0.016298 -0.249394
# Si   -0.585719 -0.239509 -0.379964  0.365415  1.000000  0.151562 -0.205398
# K    -0.392478 -0.711340  0.521925 -0.016298  0.151562  1.000000 -0.428981
# Ca    0.728543  0.078712 -0.437084 -0.249394 -0.205398 -0.428981  1.000000
# Ba   -0.131230  0.572565 -0.677868  0.492314  0.255793 -0.511976 -0.075436
# Fe    0.033936 -0.204778  0.094806 -0.123128  0.026444  0.092395  0.051292
# Type -0.083840  0.590922 -0.825391  0.581662  0.284003 -0.560027  0.223315
#
#             Ba        Fe      Type
# RI   -0.131230  0.033936 -0.083840
# Na    0.572565 -0.204778  0.590922
# Mg   -0.677868  0.094806 -0.825391
# ...

# %%
correlation= glass.corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation, cbar=True, square=True, annot=True,cmap= 'coolwarm')
plt.show()

# %% [markdown]
# Our Diagram shows correaltion between different features Conclusion:
#
#
#
# * RI and Ca have strong correlation between each other
#
# *  AI and ba have intermediate correlation between each other

# %%
glass=glass.drop(columns="Ca")
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...  ...   ...
# 206  1.51645  14.94  0.00  1.87  73.11  0.00  1.38  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  1.67  0.0     7
#
# [174 rows x 9 columns]

# %% [markdown]
# ### **Boxplot to show the minimization of Outliers**

# %%
newfeatures = ['RI','Na','Mg','Al','Si','K','Ba','Fe']
for i in range(0,8):
       sns.boxplot(x = newfeatures[i],data = glass)
       plt.ylabel(newfeatures[i])
       plt.show()

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# ### **Shape of Train and Test Set**

# %%
print('Shape of X_train = ' + str(X_train.shape))
print('Shape of X_test = ' + str(X_test.shape))
print('Shape of y_train = ' + str(y_train.shape))
print('Shape of y_test = ' + str(y_test.shape))
# Out:
# Shape of X_train = (160, 9)
# Shape of X_test = (54, 9)
# Shape of y_train = (160,)
# Shape of y_test = (54,)

# %%
dic={}

# %% [markdown]
# # **Modelling Dataset**

# %% [markdown]
# ### **Non-Linear SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import time

start = time.time()
svm_model = SVC(gamma='auto').fit(X_train, y_train)
svm_predictions = svm_model.predict(X_test)

acc_train = svm_model.score(X_train, y_train)
acc_test = svm_model.score(X_test, y_test)
end = time.time()
print("Accuracy for training set: ",acc_train)
print("Accuracy for test set: ",acc_test)
dic["SVM"]=accuracy_score(y_test , svm_predictions)
print("Time Taken to run(ms): ",(end - start)*10**3)
# Out:
# Accuracy for training set:  0.7375
# Accuracy for test set:  0.6481481481481481
# Time Taken to run(ms):  16.251564025878906

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, svm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67        14
#            2       0.77      0.48      0.59        21
#            3       0.00      0.00      0.00         4
#            5       0.75      0.75      0.75         4
#            6       0.50      0.33      0.40         3
#            7       1.00      0.88      0.93         8
#
#     accuracy                           0.65        54
#    macro avg       0.59      0.57      0.56        54
# weighted avg       0.66      0.65      0.62        54
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",svm_model.score(X_train, y_train))
knncf = confusion_matrix(svm_predictions,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.7375
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# ### **Desicion Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
import time
start = time.time()
tree_model = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
tree_predictions = tree_model.predict(X_test)
end = time.time()
print("Accuracy for training set: ",tree_model.score(X_train,y_train))
print("Accuracy for test set: ",tree_model.score(X_test,y_test))
dic["DT"]=accuracy_score(y_test , tree_predictions)
print("Time Taken to run(ms): ",(end - start)*10**3)
# Out:
# Accuracy for training set:  1.0
# Accuracy for test set:  0.6851851851851852
# Time Taken to run(ms):  6.519794464111328

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, tree_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.93      0.70        14
#            2       0.77      0.48      0.59        21
#            3       0.50      0.25      0.33         4
#            5       0.67      0.50      0.57         4
#            6       0.60      1.00      0.75         3
#            7       1.00      1.00      1.00         8
#
#     accuracy                           0.69        54
#    macro avg       0.68      0.69      0.66        54
# weighted avg       0.71      0.69      0.67        54

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",tree_model.score(X_train,y_train))
knncf = confusion_matrix(tree_predictions,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  1.0
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# ### **Plot for Decision Tree**

# %%
from sklearn import tree

fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (100,100), dpi=300)
tree.plot_tree(tree_model)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **K Nearest Neighbour**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 1, cv=3, n_jobs = -1)
g_res = gs.fit(X_train, y_train)
print("Time Taken to run(ms): ",(end - start)*10**3)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# Time Taken to run(ms):  6.519794464111328

# %%
g_res.best_score_
# Out:
# 0.6752853482413231

# %%
g_res.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}

# %%
knn = KNeighborsClassifier(n_neighbors = 5, weights = 'uniform',algorithm = 'brute',metric = 'manhattan')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', metric='manhattan')

# %%
y_hat = knn.predict(X_train)
y_knn = knn.predict(X_test)

# %%
from sklearn import metrics
dic["knn"]=accuracy_score(y_test , y_knn)
print('Training set accuracy: ', metrics.accuracy_score(y_train, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(y_test, y_knn))
# Out:
# Training set accuracy:  0.7625
# Test set accuracy:  0.6296296296296297

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.52      0.93      0.67        14
#            2       0.85      0.52      0.65        21
#            3       0.00      0.00      0.00         4
#            5       1.00      0.25      0.40         4
#            6       0.50      0.67      0.57         3
#            7       0.78      0.88      0.82         8
#
#     accuracy                           0.63        54
#    macro avg       0.61      0.54      0.52        54
# weighted avg       0.68      0.63      0.61        54

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",metrics.accuracy_score(y_train, y_hat))
knncf = confusion_matrix(y_knn,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.7625
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=params, cv = 4, n_jobs=-1, verbose=1, scoring="accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# CPU times: user 1.93 s, sys: 109 ms, total: 2.04 s
# Wall time: 1min 1s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.68125

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=5, n_estimators=200,
#                        n_jobs=-1, random_state=42)

# %%
# Visualizing the decision tree with index 5 in the given random foresr

from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(rf_best.estimators_[9], feature_names = X.columns,class_names=['1','2','3','4','5','6','7'],filled=True);

# %%
from sklearn.ensemble import RandomForestClassifier
import time
start = time.time()
Scores = []

forest = RandomForestClassifier(criterion='gini',max_depth=10, min_samples_leaf=5, n_estimators=200,n_jobs=-1, random_state=42)

forest.fit(X_train, y_train)
end = time.time()
ypred = forest.predict(X_test)
score = forest.score(X_test,y_test)
forestpred = forest.score(X_train,y_train)
print(forest.score(X_train,y_train))
print(score)
dic["random"]=accuracy_score(y_test , ypred)
print("Time Taken to run(ms): ",(end - start)*10**3)
# Out:
# 0.88125
# 0.7407407407407407
# Time Taken to run(ms):  454.30755615234375

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.61      1.00      0.76        14
#            2       0.88      0.67      0.76        21
#            3       1.00      0.25      0.40         4
#            5       0.67      0.50      0.57         4
#            6       1.00      0.33      0.50         3
#            7       0.80      1.00      0.89         8
#
#     accuracy                           0.74        54
#    macro avg       0.83      0.62      0.65        54
# weighted avg       0.80      0.74      0.72        54

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",forestpred)
knncf = confusion_matrix(ypred,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.88125
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# K Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
km = KMeans(n_clusters=6)  
y_predkm= km.fit_predict(X_test)
dic["KM"]=accuracy_score(y_test , y_predkm)
accuracy_score(y_test , y_predkm)
# Out:
# 0.14814814814814814

# %%
plt.figure(figsize=(30,30))
import scipy.cluster.hierarchy as shc  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(glass[newfeatures], method='ward'))

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",accuracy_score(y_test , y_predkm))
knncf = confusion_matrix(y_predkm,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.14814814814814814
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# AGGLOMERATIVE CLUSTERING:

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')  
y_predAc=cluster.fit_predict(X_test)
dic["AC"]=accuracy_score(y_test, y_predkm)
accuracy_score(y_test , y_predAc)
# Out:
# 0.07407407407407407

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",accuracy_score(y_test , y_predAc))
knncf = confusion_matrix(y_predAc,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.07407407407407407
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# GRADIENT BOOSTING:

# %%
from sklearn.ensemble import GradientBoostingClassifier
gra = GradientBoostingClassifier(n_estimators=200 , random_state=1367)
gra.fit(X_train , y_train)
y_gra = gra.predict(X_test)
print (classification_report(y_test , y_gra))
print("Classification Accuracy = " + str(accuracy_score(y_test , y_gra)))
dic["GB"]=accuracy_score(y_test , y_gra)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      1.00      0.78        14
#            2       0.88      0.67      0.76        21
#            3       1.00      0.50      0.67         4
#            5       1.00      0.75      0.86         4
#            6       0.67      0.67      0.67         3
#            7       1.00      1.00      1.00         8
#
#     accuracy                           0.80        54
#    macro avg       0.86      0.76      0.79        54
# weighted avg       0.84      0.80      0.79        54
#
# Classification Accuracy = 0.7962962962962963

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",accuracy_score(y_test ,y_gra))
knncf = confusion_matrix(y_gra,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.7962962962962963
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %% [markdown]
# MULTI LAYER NEURAL NETWORKS (ANN)

# %%
import scipy as sc
import random
import time
from sklearn.utils import shuffle

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import linear,relu,softmax

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(150,100,100), activation='relu', solver='adam', max_iter=700)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print(metrics.accuracy_score(y_pred,y_test))
dic["NN"]=metrics.accuracy_score(y_pred,y_test)
# Out:
# 0.7037037037037037

# %%
from sklearn.metrics import confusion_matrix
print("Train ACCURACY: ",accuracy_score(y_test ,y_pred))
knncf = confusion_matrix(y_pred,y_test)
sns.heatmap(knncf,annot=True,fmt="")
plt.ylabel("Actual Positive             Actual Negative")
plt.xlabel("Predicted Negative       Predicted Positive")
# Out:
# Train ACCURACY:  0.7037037037037037
# Text(0.5, 12.5, 'Predicted Negative       Predicted Positive')

# %%
plt.plot(mlp.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()

# %%
fig, axes = plt.subplots(4, 4)
# use global min / max to ensure all weights are shown on the same scale
vmin, vmax = mlp.coefs_[0].min(), mlp.coefs_[0].max()
for coef, ax in zip(mlp.coefs_[0].T, axes.ravel()):
    ax.matshow(coef.reshape(3, 3), cmap=plt.cm.gray, vmin=0.5 * vmin, vmax=0.5 * vmax)
    ax.set_xticks(())
    ax.set_yticks(())

plt.show()

# %%
param_grid = {
    'hidden_layer_sizes': [(150,100,50), (120,80,40), (100,50,30)],
    'max_iter': [50, 100, 150, 300],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
grid = GridSearchCV(mlp, param_grid, n_jobs= -1, cv=5)
grid.fit(X_train, y_train)

print(grid.best_params_) 


grid_predictions = grid.predict(X_test) 

print(accuracy_score(y_test, grid_predictions))

# %%
plt.figure(figsize=(12,9))
names = list(dic.keys())
values = list(dic.values())

plt.bar(range(len(dic)), values, tick_label=names)
plt.show()

# %% [markdown]
# DIMENSIONALITY REDUCTION:

# %%
from sklearn.decomposition import PCA # dimensionality reduction#
pca = PCA(random_state = 1)
pca.fit(X_train)
var_exp = pca.explained_variance_ratio_
cum_var_exp = np.cumsum(var_exp)
plt.figure(figsize=(8,6))
plt.bar(range(1,len(cum_var_exp)+1), var_exp, align= 'center', label= 'individual variance explained', \
       alpha = 0.7)
plt.step(range(1,len(cum_var_exp)+1), cum_var_exp, where = 'mid' , label= 'cummulative variance explained', \
        color= 'red')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.xticks(np.arange(1,len(var_exp)+1,1))
plt.legend(loc='center right')
plt.show()

# Cumulative variance explained
var_df = pd.DataFrame(pca.explained_variance_.round(2), index=["P" + str(i) for i in range(1,10)],
                      columns=["Explained_Variance"])
print(var_df.T)

# %% [markdown]
# It appears that about 99 % of the variance can be explained with the first 5 principal components. However feeding the PCA features to the learning algorithms did not contribute to a better performance.

# %%
pca_red = PCA(n_components=5)
X_reduced = pca_red.fit_transform(X_train)

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import libraries
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
clf = LazyClassifier( verbose=0, ignore_warnings=True, custom_metric=None)
models_train, predictions_train = clf.fit( X_train, X_train, y_train, y_train )
models_test, predictions_test = clf.fit( X_train, X_test, y_train, y_test )
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  6.35it/s]
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|██████████| 29/29 [00:03<00:00,  9.16it/s]

# %%
# Prints the model performance on test dataset
models_test
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.80               0.81    None      0.80
# BaggingClassifier                  0.76               0.80    None      0.75
# LabelPropagation                   0.76               0.77    None      0.76
# LabelSpreading                     0.76               0.77    None      0.76
# LGBMClassifier                     0.80               0.77    None      0.79
# RandomForestClassifier             0.78               0.77    None      0.77
# XGBClassifier                      0.78               0.73    None      0.76
# Perceptron                         0.65               0.71    None      0.62
# DecisionTreeClassifier             0.69               0.69    None      0.67
# PassiveAggressiveClassifier        0.67               0.68    None      0.65
# LinearSVC                          0.70               0.67    None      0.67
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="Accuracy", data=models_train)

# %% [markdown]
# ### Inference
# - From this plot we can easily see that the best model to predict `Glass Type` in our case will start from  Random Forest and Decision Tree
# - then Gradient Boosting and Random Forest and so on
